# %%
# s_woo = pd.read_csv('./s_woo.csv',encoding='euc-kr')
# s_woo
# 변수가 좁혀진 데이터

# %%
import pandas as pd

# %% [markdown]
# - fin_raw_data

# %%
fin_raw_data = pd.read_csv('./fin_raw_data.csv',encoding='euc-kr')

# %%
fin_raw_data
# Out:
#               날짜    달러원종가    달러원시가  CD91   WTI가  달러위안화     달러엔    달러인덱스  유로달러  \
# 0     2010-01-04  1150.00  1164.07  2.88  81.64   6.83   92.47   92.36   1.44
# 1     2010-01-05  1140.20  1151.00  2.88  81.47   6.83   91.58   92.22   1.44
# 2     2010-01-06  1129.20  1140.20  2.88  83.25   6.83   92.38   92.09   1.44
# 3     2010-01-07  1138.20  1129.20  2.88  82.69   6.83   93.45   92.37   1.43
# 4     2010-01-08  1128.25  1135.50  2.88  82.91   6.83   92.68   92.15   1.44
# ...          ...      ...      ...   ...    ...    ...     ...      ...   ...
# 3313  2023-09-11  1325.49  1336.34  3.72  87.42   7.29  146.58  121.82   1.07
# 3314  2023-09-12  1326.15  1326.05  3.73  88.94   7.29  147.08  121.77   1.08
# 3315  2023-09-13  1326.59  1326.72  3.75  88.80   7.27  147.45  121.55   1.07
# 3316  2023-09-14  1329.52  1328.20  3.76  90.67   7.28  147.47  121.72   1.06
# 3317  2023-09-15  1328.46  1330.02  3.78  91.15   7.27  147.82  121.68   1.07
#
# ...

# %% [markdown]
# - raw_data2

# %%
raw_data2 = pd.read_csv('./raw_data2.csv',encoding='euc-kr')

# %%
raw_data2
# Out:
#               날짜    달러원종가    달러원시가  CD91   WTI가  달러위안화     달러엔   달러인덱스  유로달러  \
# 0     2010-01-04  1150.00  1164.07  2.88  81.64   6.83   92.47   92.36  1.44
# 1     2010-01-05  1140.20  1151.00  2.88  81.47   6.83   91.58   92.22  1.44
# 2     2010-01-06  1129.20  1140.20  2.88  83.25   6.83   92.38   92.09  1.44
# 3     2010-01-07  1138.20  1129.20  2.88  82.69   6.83   93.45   92.37  1.43
# 4     2010-01-08  1128.25  1135.50  2.88  82.91   6.83   92.68   92.15  1.44
# ...          ...      ...      ...   ...    ...    ...     ...     ...   ...
# 3313  2023-09-11  1325.49  1336.34  3.72  87.42   7.29  146.58  121.82  1.07
# 3314  2023-09-12  1326.15  1326.05  3.73  88.94   7.29  147.08  121.77  1.08
# 3315  2023-09-13  1326.59  1326.72  3.75  88.80   7.27  147.45  121.55  1.07
# 3316  2023-09-14  1329.52  1328.20  3.76  90.67   7.28  147.47  121.72  1.06
# 3317  2023-09-15  1328.46  1330.02  3.78  91.15   7.27  147.82  121.68  1.07
#
#        유로인덱스   콜금리    코스피종가
# ...

# %% [markdown]
# Woo_data_3

# %%
Woo_data_3 = pd.read_csv('./Woo_data_3.csv',encoding='euc-kr')

# %%
Woo_data_3
# Out:
#               날짜  위안화원_시  유로달러_시        코스피시가  유로인덱스_시   달러엔_시  달러위안화_시  \
# 0     2010-01-04  170.51  1.4325  1681.709961    92.75   92.75   6.8297
# 1     2010-01-05  168.56  1.4409  1701.619995    92.47   92.47   6.8283
# 2     2010-01-06  167.02  1.4364  1697.880005    91.56   91.56   6.8277
# 3     2010-01-07  165.36  1.4407  1702.920044    92.36   92.36   6.8269
# 4     2010-01-08  166.29  1.4320  1694.060059    93.46   93.46   6.8278
# ...          ...     ...     ...          ...      ...     ...      ...
# 3313  2023-09-11  181.96  1.0716  2549.879883   147.02  147.02   7.3236
# 3314  2023-09-12  181.92  1.0751  2566.419922   146.59  146.59   7.2872
# 3315  2023-09-13  181.95  1.0754  2536.219971   147.07  147.07   7.2842
# 3316  2023-09-14  182.67  1.0729  2544.889893   147.46  147.46   7.2732
# 3317  2023-09-15  182.74  1.0639  2574.979980   147.49  147.49   7.2804
#
#         달러원종가    달러원시가  CD91    WTI   달러인덱스   콜금리   BIR     엔원_시
# ...

# %% [markdown]
# 환율신호등raw_data_

# %%
환율신호등raw_data_ = pd.read_csv('./환율신호등raw_data_.csv',encoding='euc-kr', index_col=0)

# %%
환율신호등raw_data_
# Out:
#               날짜    달러원종가    달러원시가  CD91   WTI가   달러위안화     달러엔     달러인덱스  \
# 0     2010-01-04  1150.00  1164.07  2.88  81.64  6.8285   92.47   92.3566
# 1     2010-01-05  1140.20  1151.00  2.88  81.47  6.8268   91.58   92.2236
# 2     2010-01-06  1129.20  1140.20  2.88  83.25  6.8278   92.38   92.0941
# 3     2010-01-07  1138.20  1129.20  2.88  82.69  6.8281   93.45   92.3684
# 4     2010-01-08  1128.25  1135.50  2.88  82.91  6.8276   92.68   92.1485
# ...          ...      ...      ...   ...    ...     ...     ...       ...
# 3313  2023-09-11  1325.49  1336.34  3.72  87.42  7.2882  146.58  121.8185
# 3314  2023-09-12  1326.15  1326.05  3.73  88.94  7.2910  147.08  121.7721
# 3315  2023-09-13  1326.59  1326.72  3.75  88.80  7.2700  147.45  121.5454
# 3316  2023-09-14  1329.52  1328.20  3.76  90.67  7.2770  147.47  121.7192
# 3317  2023-09-15  1328.46  1330.02  3.78  91.15  7.2744  147.82  121.6815
#
#         유로달러   유로인덱스    콜금리        코스피종가   BIR    위안화원       엔원
# ...

# %%
print(fin_raw_data.columns)
print(raw_data2.columns)
print(Woo_data_3.columns)
print(환율신호등raw_data_.columns)
# Out:
# Index(['날짜', '달러원종가', '달러원시가', 'CD91', 'WTI가', '달러위안화', '달러엔', '달러인덱스', '유로달러',
#        '유로인덱스', '콜금리', '코스피종가', 'BIR', '위안화원', '엔원'],
#       dtype='object')
# Index(['날짜', '달러원종가', '달러원시가', 'CD91', 'WTI가', '달러위안화', '달러엔', '달러인덱스', '유로달러',
#        '유로인덱스', '콜금리', '코스피종가'],
#       dtype='object')
# Index(['날짜', '위안화원_시', '유로달러_시', '코스피시가', '유로인덱스_시', '달러엔_시', '달러위안화_시',
#        '달러원종가', '달러원시가', 'CD91', 'WTI', '달러인덱스', '콜금리', 'BIR', '엔원_시'],
#       dtype='object')
# Index(['날짜', '달러원종가', '달러원시가', 'CD91', 'WTI가', '달러위안화', '달러엔', '달러인덱스', '유로달러',
#        '유로인덱스', '콜금리', '코스피종가', 'BIR', '위안화원', '엔원'],
#       dtype='object')
